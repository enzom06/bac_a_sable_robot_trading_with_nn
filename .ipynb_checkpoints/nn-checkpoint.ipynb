# %%
# Matplotlib
import matplotlib.pyplot as plt
from tensorflow.keras.optimizers import SGD
import sklearn
import tensorflow as tf
from zigzag import *
import pandas as pd
import numpy as np
import pickle
# Numpy and Pandas
# Ohter import
import time
import sys

# %%
assert hasattr(tf, "function") # Be sure to use tensorflow 2.0

# %%
def indicator_mod(az):
    indic = az
    maxx = -9999
    minn = 9999
    for i in range(len(indic)):
        x = indic[i]
        for val in x:
            if val != x[-1]:
                if val > maxx:
                    maxx = val
                if val < minn:
                    minn = val
        for xi in range(len(x) - 1):
            indic[i][xi] = (indic[i][xi] - minn) / (maxx - minn)
            # indic[i] = (indic[i] - minn) / (maxx - minn)
    return indic

def indicator_mod_simple(az):
    x = az
    maxx = -9999
    minn = 9999
    for val in x:
        if val > maxx:
            maxx = val
        if val < minn:
            minn = val
    
    for xi in range(len(x)):
        if (x[xi] - minn) / (maxx - minn+0.0001)>1:
            x[xi] = 1
        else:
            x[xi] = (x[xi] - minn) / (maxx - minn+0.00000001)
            # indic[i] = (indic[i] - minn) / (maxx - minn)
    return x

# %%
def prepa_data(lst_open, lst_high, lst_low, lst_close):
    lst_x_input = []
    for i in range(23, len(lst_open)):
        lst_temp = []
        for i2 in range(24):
            lst_temp.append(lst_open[i - i2])
        #for i2 in range(6):
        #    lst_temp.append(lst_high[i - i2])
        #for i2 in range(6):
        #    lst_temp.append(lst_low[i - i2])
        for i2 in range(24):
            lst_temp.append(lst_close[i - i2])
        lst_x_input.append(list(sklearn.preprocessing.minmax_scale([lst_temp], feature_range=(0, 1), axis=0, copy=True)))
    return lst_x_input

# %%
def plot_pivots(X, pivots):
    plt.plot(np.arange(len(X)), X, 'k:', alpha=0.5)
    plt.plot(np.arange(len(X))[pivots != 0], X[pivots != 0], 'k-')
    plt.scatter(np.arange(len(X))[pivots == -1], X[pivots == -1], color='g')
    plt.scatter(np.arange(len(X))[pivots == 1], X[pivots == 1], color='r')

# %%
in_long_trade = False
buy_part = 100
ref_price = 0
precision = 10
reserve = 1000
position = 0
nb_bon_trade = 0
nb_total_trade = 0
def buy_sell_trade(actu_choice, actu_choice_2, close_price):
    global in_long_trade, buy_part, ref_price, precision, reserve, position, nb_bon_trade, nb_total_trade
    choice_final = 0
    if actu_choice > 0.5:
        # pas de short nous on utilise spot
        if not in_long_trade:
                if reserve > buy_part:
                    # print('start long')
                    ref_price = close_price
                    reserve -= buy_part
                    reserve -= (buy_part * 0.0750 / 100) * 1
                    position = round(buy_part / ref_price, precision)
                    in_long_trade = True
                    choice_final = -1
                    # print('open ', close_price, lst_price_open[i], lst_price_x_open[i])
                    # print('close', lst_price_x_close[i], lst_price_close[i])
    elif actu_choice_2 > 0.5:
        if in_long_trade:
            # print('stop long')
            reserve += position * close_price
            reserve -= (position * close_price * 0.0750 / 100) * 1
            in_long_trade = False
            if (position * close_price) - buy_part > 0:
                nb_bon_trade += 1
            nb_total_trade += 1
            choice_final = 1
            # print('open ', close_price, lst_price_open[i], lst_price_x_open[i])
            # print('close', lst_price_x_close[i], lst_price_close[i])

    return choice_final

# %%
with open("data_train.data", "rb") as fic:
    candlesticks = pickle.load(fic)

with open("data_test.data", "rb") as fic:
    candlesticks2 = pickle.load(fic)

# %%
## data = candlesticks
data = candlesticks
df = pd.DataFrame(data=data,
                  columns=["open_time", "open", "high", "low", "close", "volume", "close_time",
                           "quote_asset_volume",
                           "nb_volume", "taker_buy_base_asset_volume", "taker_buy_quote_asset_asset_volume",
                           "ignored"],
                  dtype=float)
df = df.copy()

# uniformiser les données
lst_price_open = df.open.values[27:]
lst_price_high = df.high.values[27:]
lst_price_low = df.low.values[27:]
lst_price_close = df.close.values[27:]
normalizer.adapt(lst_price_open)
normalizer.adapt(lst_price_high)
normalizer.adapt(lst_price_low)
normalizer.adapt(lst_close)

lst_x_input = prepa_data(lst_price_open, lst_price_high, lst_price_low, lst_price_close)

pivots = peak_valley_pivots(lst_price_close, 0.03, -0.03)

#lst_x_input = indicator_mod(lst_x_input)
lst_price_open = lst_price_open[23:]
lst_price_high = lst_price_high[23:]
lst_price_low = lst_price_low[23:]
lst_price_close = lst_price_close[23:]
pivots = pivots[23:]

print('set x input')


for i in range(len(lst_x_input)):
    one = lst_x_input[i][0:24]
    two = lst_x_input[i][24:48]
    #tree = lst_x_input[i][12:18]
    #f = lst_x_input[i][18:24]
    #
    #one = preprocessing.normalize(one)
    #two = preprocessing.normalize(two)
    #tree = preprocessing.normalize(tree)
    #f = preprocessing.normalize(f)
    lst_x_input[i] = [one, two]
lst_x_input = np.array(lst_x_input)

#plot_pivots(lst_price_close, pivots)
print('set data')
train_data = []
targets_data = []
for i in range(len(pivots)):
    if pivots[i] == -1:
        train_data.append(lst_x_input[i])
        targets_data.append(0.01)
        #pivots[i] = -1
    elif pivots[i] == 1:
        train_data.append(lst_x_input[i])
        targets_data.append(1.99)
        #pivots[i] = 1
train_data = np.array(train_data)
targets_data = np.array(targets_data)
print('good data')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-621-3647d1f4d445> in <module>
#      14 lst_price_low = df.low.values[27:]
#      15 lst_price_close = df.close.values[27:]
# ---> 16 normalizer.adapt(lst_price_open)
#      17 normalizer.adapt(lst_price_high)
#      18 normalizer.adapt(lst_price_low)
#
# ~\anaconda3\envs\Bot_last\lib\site-packages\tensorflow\python\keras\engine\base_preprocessing_layer.py in adapt(self, data, batch_size, steps, reset_state)
#     240             When training with input tensors such as
#     241             TensorFlow data tensors, the default `None` is equal to
# --> 242             the number of samples in your dataset divided by
#     243             the batch size, or 1 if that cannot be determined. If x is a
#     244             `tf.data` dataset, and 'steps' is None, the epoch will run until
#
# ~\anaconda3\envs\Bot_last\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     887         return self._python_function(*args, **kwds)
#     888
# --> 889     # Only count the statistics the first time, before initialization took
#     890     # place.
#     891     if self._created_variables is None:
#
# ~\anaconda3\envs\Bot_last\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     931     self._lock.acquire()
#     932     if ALLOW_DYNAMIC_VARIABLE_CREATION:
# --> 933       condition = self._created_variables and self._stateful_fn is None
#     934     else:
#     935       condition = self._created_variables
#
# ~\anaconda3\envs\Bot_last\lib\site-packages\tensorflow\python\eager\def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     761
#     762     created_variables = []
# --> 763     lifted_initializer_graph = func_graph_module.FuncGraph("initializer")
#     764
#     765     def variable_capturing_scope(unused_next_creator, **kwds):
#
# ~\anaconda3\envs\Bot_last\lib\site-packages\tensorflow\python\eager\function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    3048   defined functions.
#    3049
# -> 3050   `Function` class is thread-compatible meaning that minimal usage of defuns
#    3051   (defining and calling) is thread-safe, but if users call other methods or
#    3052   invoke the base `python_function` themselves, external synchronization is
#
# ~\anaconda3\envs\Bot_last\lib\site-packages\tensorflow\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    3442
#    3443     if (relaxed_arg_function is not None
# -> 3444         and all(_is_type_subset(x, y) for (x, y) in
#    3445                 zip(relaxed_arg_specs, arg_specs))):
#    3446       return relaxed_arg_function, filtered_flat_args
#
# ~\anaconda3\envs\Bot_last\lib\site-packages\tensorflow\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3277       self._descriptor_cache[instance] = class_method_to_instance_method(
#    3278           self, instance)
# -> 3279
#    3280     # Return the cached `Function` for the instance
#    3281     return self._descriptor_cache[instance]
#
# ~\anaconda3\envs\Bot_last\lib\site-packages\tensorflow\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     997       The current allowlisted collections are the global variables, the
#     998       local variables, and the trainable variables.
# --> 999       Defaults to None.
#    1000     capture_by_value: An optional boolean. If True, the func graph will capture
#    1001       Variables by value instead of reference. By default inherit from outer
#
# ~\anaconda3\envs\Bot_last\lib\site-packages\tensorflow\python\eager\def_function.py in wrapped_fn(*args, **kwds)
#     670         # the function a weak reference to itself to avoid a reference cycle.
#     671         with OptionalXlaContext(compile_with_xla):
# --> 672           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     673         return out
#     674
#
# ~\anaconda3\envs\Bot_last\lib\site-packages\tensorflow\python\framework\func_graph.py in wrapper(*args, **kwargs)
#     984       See https://www.tensorflow.org/guide/autograph for more information.
#     985     add_control_dependencies: If True, automatically adds control dependencies
# --> 986       to ensure program order matches execution order and stateful ops always
#     987       execute.
#     988     arg_names: Optional list of argument names, used to give input placeholders
#
# NameError: in user code:
#
#     C:\Users\M\anaconda3\envs\Bot_last\lib\site-packages\tensorflow\python\keras\engine\base_preprocessing_layer.py:149 adapt_fn  *
#         adapt_step(iterator)
#
#     NameError: name 'adapt_step' is not defined

# %%
[10,50,70, 100, 20] + [80, 20, 10]
list(sklearn.preprocessing.minmax_scale([[8.00, 8.510, 8.00]], feature_range=(0, 1), axis=0, copy=True))[0]
#preprocessing.normalize([[8.00, 8.510, 8.00]])
#indicator_mod(lst_price_open[:10])
# Out:
# array([0., 0., 0.])

# %%
plot_pivots(lst_price_close[:1000], pivots[:1000])

# %%
lst_x_input[0]
# Out:
# array([[0.16396631, 0.6152724 , 0.69412405, 0.59994554, 0.58351001,
#         0.54301441, 0.64273627, 0.63217474, 0.66261451, 0.7841791 ,
#         0.86198043, 0.89726334, 0.82980958, 0.8777741 , 1.        ,
#         0.82099858, 0.64964114, 0.67973081, 0.62182716, 0.50551417,
#         0.54842161, 0.7373427 , 0.57650789, 0.67722171],
#        [0.        , 0.16727287, 0.61389143, 0.69758621, 0.59572482,
#         0.57695524, 0.54291716, 0.64273627, 0.63378912, 0.66348978,
#         0.78419855, 0.86124132, 0.9006088 , 0.83052924, 0.87226966,
#         0.99990275, 0.81520238, 0.64925213, 0.68286231, 0.62182716,
#         0.50549472, 0.54756579, 0.73057398, 0.58135102]])

# %%
normalizer = tf.keras.layers.experimental.preprocessing.Normalization(axis=-1)

# %%
def get_basic_model():
    model = tf.keras.Sequential([
    normalizer,
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(1)
  ])

    model.compile(optimizer='adam',
                loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
                metrics=['accuracy'])
    return model

# %%
history = model.fit(train_data, targets_data, epochs=100, batch_size=1)
# Out:
# Epoch 1/100
# 410/410 [==============================] - 1s 939us/step - loss: 0.6581 - accuracy: 0.0000e+000s - loss: 0.6304 - accuracy: 0.
# Epoch 2/100
# 410/410 [==============================] - 0s 1ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 3/100
# 410/410 [==============================] - 1s 1ms/step - loss: 0.6931 - accuracy: 0.0000e+00: 0s - loss: 0.6931 - accuracy:
# Epoch 4/100
# 410/410 [==============================] - 1s 1ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 5/100
# 410/410 [==============================] - 1s 1ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 6/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 7/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 8/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 9/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 10/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 11/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 12/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 13/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 14/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 15/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 16/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 17/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 18/100
# 410/410 [==============================] - 0s 1ms/step - loss: 0.6931 - accuracy: 0.0000e+00: 0s - loss: 0.6931 - accura
# Epoch 19/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 20/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 21/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 22/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 23/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 24/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 25/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 26/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 27/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 28/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 29/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 30/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 31/100
# 410/410 [==============================] - 1s 1ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 32/100
# 410/410 [==============================] - 0s 1ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 33/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 34/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 35/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 36/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 37/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 38/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 39/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 40/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 41/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 42/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 43/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 44/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 45/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 46/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 47/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 48/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 49/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 50/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 51/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 52/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 53/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 54/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 55/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 56/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 57/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 58/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 59/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 60/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 61/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 62/100
# 410/410 [==============================] - 1s 1ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 63/100
# 410/410 [==============================] - 0s 1ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 64/100
# 410/410 [==============================] - 1s 1ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 65/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 66/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 67/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 68/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 69/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 70/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 71/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 72/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 73/100
# 410/410 [==============================] - 1s 1ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 74/100
# 410/410 [==============================] - 1s 1ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 75/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 76/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 77/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 78/100
# 410/410 [==============================] - 0s 1ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 79/100
# 410/410 [==============================] - 0s 1ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 80/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 81/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 82/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 83/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 84/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 85/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 86/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 87/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 88/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 89/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 90/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 91/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 92/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 93/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 94/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 95/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 96/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 97/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 98/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 99/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 100/100
# 410/410 [==============================] - 1s 2ms/step - loss: 0.6931 - accuracy: 0.0000e+00

# %%
#history = model.fit(train_data, targets_data, epochs=10, validation_split=0.2)

# %%
loss_curve = history.history["loss"]
acc_curve = history.history["accuracy"]

loss_val_curve = history.history["val_loss"]
acc_val_curve = history.history["val_accuracy"]

plt.plot(loss_curve, label="Train")
plt.plot(loss_val_curve, label="Val")
plt.legend(loc='upper left')
plt.title("Loss")
plt.show()

plt.plot(acc_curve, label="Train")
plt.plot(acc_val_curve, label="Val")
plt.legend(loc='upper left')
plt.title("Accuracy")
plt.show()

# %%
loss, acc = model.evaluate(train_data, targets_data)
print("Test Loss", loss)
print("Test Accuracy", acc)

# %%
#n = np.array([[1, 2, 3, 4]])

#np.argmax(n[0])
